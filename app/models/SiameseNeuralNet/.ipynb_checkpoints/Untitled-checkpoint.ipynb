# %%
import pickle
pickle_in = open("../../../final_outputs.pkl", "rb")
outputs = pickle.load(pickle_in)

# %%
outputs
# Out:
# [tensor([[-0.0083,  0.0508]], requires_grad=True),
#  tensor([[ 0.0383, -0.0154]], requires_grad=True),
#  tensor([[-0.0708, -0.0295]], requires_grad=True),
#  tensor([[-0.0727, -0.0281]], requires_grad=True),
#  tensor([[-0.0073,  0.0506]], requires_grad=True),
#  tensor([[-0.0063,  0.0502]], requires_grad=True),
#  tensor([[-0.0087,  0.0522]], requires_grad=True),
#  tensor([[-0.0082,  0.0497]], requires_grad=True),
#  tensor([[-0.0054,  0.0495]], requires_grad=True),
#  tensor([[-0.0069,  0.0521]], requires_grad=True),
#  tensor([[ 0.0391, -0.0160]], requires_grad=True),
#  tensor([[ 0.0386, -0.0156]], requires_grad=True),
#  tensor([[ 0.0390, -0.0148]], requires_grad=True),
#  tensor([[ 0.0385, -0.0169]], requires_grad=True),
#  tensor([[ 0.0398, -0.0166]], requires_grad=True),
#  tensor([[ 0.0393, -0.0155]], requires_grad=True),
#  tensor([[ 0.0388, -0.0157]], requires_grad=True),
#  tensor([[ 0.0387, -0.0160]], requires_grad=True),
# ...

# %%
import numpy as np
a = np.asarray(outputs)

# %%
a.tofile('foo.csv',sep=',')

# %%
import pandas as pd
pd.read_csv("foo.csv")

# %%
import os as s
